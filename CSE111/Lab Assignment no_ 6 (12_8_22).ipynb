# %%
# Task-1

class Student:
  ID = 0
  def __init__(self,n,d,a,cg):
    self.n = n
    self.d = d
    self.a = a
    self.cg = cg
    Student.ID += 1

  def get_details(self):
    # return (f'ID: {Student.ID}\nName: {self.n}\nDepartment: {self.d}\nAge: {self.a}\nCGPA: {self.cg}')
    print('ID: ', Student.ID)
    print('Name: ', self.n)
    print('Department: ', self.d)
    print('Age: ', self.a)
    print('CGPA: ', self.cg)

  @classmethod
  def from_String(cls,v):
    spl = v.split('-')
    a = spl[0]
    b = spl[1]
    c = spl[2]
    d = spl[3]

    return cls(a,b,c,d)
  


#Write your code here for subtasks 1-6.
s1 = Student("Samin", "CSE", 21, 3.91)
s1.get_details()
print("-----------------------")
s2 = Student("Fahim", "ECE", 21, 3.85)
s2.get_details()
print("-----------------------")
s3 = Student("Tahura", "EEE", 22, 3.01)
s3.get_details()
print("-----------------------")
s4 = Student.from_String("Sumaiya-BBA-23-3.96")
s4.get_details()

# Write the answer of subtask 5 here
# Write the answer of subtask 6 here

#You are not allowed to change the code above
# Out:
# ID:  1
# Name:  Samin
# Department:  CSE
# Age:  21
# CGPA:  3.91
# -----------------------
# ID:  2
# Name:  Fahim
# Department:  ECE
# Age:  21
# CGPA:  3.85
# -----------------------
# ID:  3
# Name:  Tahura
# Department:  EEE
# Age:  22
# CGPA:  3.01
# -----------------------
# ID:  4
# Name:  Sumaiya
# Department:  BBA
# Age:  23
# CGPA:  3.96

# %%
# Task-2

class Assassin:
  noa = 0
  def __init__(self,n,sr):
    self.n = n
    self.sr = sr
    Assassin.noa += 1

  def printDetails(self):
    print('Name:',self.n)
    print(f'Success rate: {self.sr}%')
    print('Total number of Assassin:',Assassin.noa)

  @classmethod
  def failureRate(cls,n,sr):
    sr = 100 - sr
    return cls(n,sr)

  @classmethod
  def failurePercentage(cls,n,sr):
    x = sr[0:2]
    sr = 100 - int(x)
    return cls(n,sr)
    

# Write your code here
john_wick = Assassin('John Wick', 100)
john_wick.printDetails()
print('================================')
nagisa = Assassin.failureRate("Nagisa", 20)
nagisa.printDetails()
print('================================')
akabane = Assassin.failurePercentage("Akabane", "10%")
akabane.printDetails()
# Out:
# Name: John Wick
# Success rate: 100%
# Total number of Assassin: 1
# ...
# Name: Nagisa
# Success rate: 80%
# Total number of Assassin: 2
# ...
# Name: Akabane
# Success rate: 90%
# Total number of Assassin: 3

# %%
# Task-3

class Passenger:
  count = 0
  def __init__(self,n):
    self.n = n
    self.bw = 0
    self.bf = 450
    Passenger.count += 1

  def set_bag_weight(self,w):
    self.bw = w

  def printDetail(self):
    print('Name: ',self.n)
    if 21<=self.bw<=50:
      bf = self.bf + 50
    elif self.bw>50:
      bf = self.bf + 100
    else:
      bf = self.bf
    print('Bus Fare:',bf)


# Write your code here
print('Total Passenger:', Passenger.count)
p1 = Passenger('Jack')
p1.set_bag_weight(90)
p2 = Passenger('Carol')
p2.set_bag_weight(10)
p3 = Passenger('Mike')
p3.set_bag_weight(25)
print("=========================")
p1.printDetail()
print("=========================")
p2.printDetail()
print("=========================")
p3.printDetail()
print("=========================")
print('Total Passenger:', Passenger.count)
# Out:
# Total Passenger: 0
# ...
# Name:  Jack
# Bus Fare: 550
# ...
# Name:  Carol
# Bus Fare: 450
# ...
# Name:  Mike
# Bus Fare: 500
# ...
# Total Passenger: 3

# %%
# Task-4

class Travel:
  count = 0
  def __init__(self,s,d):
    self.s = s
    self.d = d
    self.tt = 1
    Travel.count += 1

  def display_travel_info(self):
    return (f'Source: {self.s}\nDestination: {self.d}\nFlight Time: {self.tt}:00')


  def set_time(self,ntt):
    self.tt = ntt

  def set_destination(self,nd):
    self.d = nd

  def set_source(self,ns):
    self.s = ns



# Write your code here
print("No. of Traveller =", Travel.count)
print("=======================")
t1 = Travel("Dhaka","India")
print(t1.display_travel_info())
print("=======================")
t2 = Travel("Kuala Lampur","Dhaka")
t2.set_time(23)
print(t2.display_travel_info())
print("=======================")
t3 = Travel("Dhaka","New_Zealand")
t3.set_time(15)
t3.set_destination("Germany")
print(t3.display_travel_info())
print("=======================")
t4 = Travel("Dhaka","India")
t4.set_time(9)
t4.set_source("Malaysia")
t4.set_destination("Canada")
print(t4.display_travel_info())
print("=======================")
print("No. of Traveller =", Travel.count)
# Out:
# No. of Traveller = 0
# ...
# Source: Dhaka
# Destination: India
# Flight Time: 1:00
# ...
# Source: Kuala Lampur
# Destination: Dhaka
# Flight Time: 23:00
# ...
# Source: Dhaka
# Destination: Germany
# Flight Time: 15:00
# ...
# Source: Malaysia
# Destination: Canada
# Flight Time: 9:00
# ...
# No. of Traveller = 4

# %%
# Task-5

class Employee:
  def __init__(self,n,wp):
    self.name= n
    self.workingPeriod = wp

  @classmethod
  def employeeByJoiningYear(cls,n,y):
    return cls(n,2022-y)

  @staticmethod
  def experienceCheck(ex,g):
    if g == 'male' and ex<3:
      return ('He is not experienced')

    elif g == 'male' and ex>3:
      return ('He is experienced')

    elif g == 'female' and ex<3:
      return ('She is not experienced')

    else: 
      return ('She is experienced')




# Write your code here
employee1 = Employee('Dororo', 3)
employee2 = Employee.employeeByJoiningYear('Harry', 2016)
print(employee1.workingPeriod)
print(employee2.workingPeriod)
print(employee1.name)
print(employee2.name)
print(Employee.experienceCheck(2, "male"))
print(Employee.experienceCheck(3, "female"))
# Out:
# 3
# 6
# Dororo
# Harry
# He is not experienced
# She is experienced

# %%
# Task-6

class Laptop:
  laptopCount = 0
  def __init__(self,n,c):
    self.name = n
    self.count = c
    Laptop.laptopCount += c

  @staticmethod
  def advantage():
    print('Laptops are portable')

  @staticmethod
  def resetCount():
    Laptop.laptopCount = 0


# Write your code here
lenovo = Laptop("Lenovo", 5);
dell = Laptop("Dell", 7);
print(lenovo.name, lenovo.count)
print(dell.name, dell.count)
print("Total number of Laptops", Laptop.laptopCount)
Laptop.advantage()
Laptop.resetCount()
print("Total number of Laptops", Laptop.laptopCount)
# Out:
# Lenovo 5
# Dell 7
# Total number of Laptops 12
# Laptops are portable
# Total number of Laptops 0

# %%
# Task-7

class Cat:
  Number_of_cats = 0
  def __init__(self,clr,pos):
    self.clr = clr
    self.pos = pos
    Cat.Number_of_cats += 1

  @classmethod
  def no_parameter(cls):
    return cls('White','sitting')

  @classmethod
  def first_parameter(cls,fp):
    return cls(fp,'sitting')

  @classmethod
  def second_parameter(cls,sp):
    return cls('Grey',sp)

  def changeColor(self,cc):
    self.clr = cc

  def printCat(self):
    print(f'{self.clr} cat is {self.pos}')




# Write your code here
print("Total number of cats:", Cat.Number_of_cats)
c1 = Cat.no_parameter()
c2 = Cat.first_parameter("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c5 = Cat.second_parameter("playing")
print("=======================")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c5.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
print("=======================")
print("Total number of cats:", Cat.Number_of_cats)
# Out:
# Total number of cats: 0
# ...
# White cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Grey cat is playing
# Blue cat is sitting
# Purple cat is jumping
# ...
# Total number of cats: 5

# %%
# Task-8

import math

class Cylinder:
  radius = 5
  height = 18
  
  def __init__(self,r,h):
    self.radius = r
    self.height = h
    print(f'Default radius={Cylinder.radius} and height={Cylinder.height}.')
    Cylinder.radius = r
    Cylinder.height = h
    print(f'Updated: radius={Cylinder.radius} and height={Cylinder.height}.')

  @classmethod
  def swap(cls,r,d):
    # cls.radius = d
    # cls.height = r
    obj = Cylinder(d,r)
    return obj

  @classmethod
  def changeFormat(cls,mix):
    a,b = mix.split('-')
    # cls.radius = float(a)
    # cls.height = float(b)
    obj = Cylinder(float(a),float(b))
    return obj


  @staticmethod
  def area(sr,sh):
    print('Area:',2*math.pi*sr*(sr+sh))

  @staticmethod
  def volume(sr,sh):
    print('Volume:',math.pi*math.pow(sr,2)*sh)


# Write your code here
c1 = Cylinder(0,0)
Cylinder.area(c1.radius,c1.height)
Cylinder.volume(c1.radius,c1.height)
print("===============================")
c2 = Cylinder.swap(8,3)
c2.area(c2.radius,c2.height)
c2.volume(c2.radius,c2.height)
print("===============================")
c3 = Cylinder.changeFormat("7-13")
c3.area(c3.radius,c3.height)
c3.volume(c3.radius,c3.height)
print("===============================")
Cylinder(0.3,5.56).area(Cylinder.radius,Cylinder.height)
print("===============================")
Cylinder(3,5).volume(Cylinder.radius,Cylinder.height)
# Out:
# Default radius=5 and height=18.
# Updated: radius=0 and height=0.
# Area: 0.0
# Volume: 0.0
# ...
# Default radius=0 and height=0.
# Updated: radius=3 and height=8.
# Area: 207.34511513692635
# Volume: 226.1946710584651
# ...
# Default radius=3 and height=8.
# Updated: radius=7.0 and height=13.0.
# Area: 879.645943005142
# Volume: 2001.1945203366981
# ...
# Default radius=7.0 and height=13.0.
# Updated: radius=0.3 and height=5.56.
# Area: 11.045839770021711
# ...
# Default radius=0.3 and height=5.56.
# Updated: radius=3 and height=5.
# Volume: 141.3716694115407

# %%
# Task-9

class Student:

    total_student = 0
    brac_student = 0
    other_student = 0

    def __init__(self, name, dept, institute="BRAC University"):
        self.name = name
        self.dept = dept
        self.institute = institute

        if institute == "BRAC University":
            Student.brac_student += 1
        else:
            Student.other_student += 1

        Student.total_student += 1

    def individualDetail(self):
        print(f"Name: {self.name}")
        print(f"Department: {self.dept}")
        print(f"Institution: {self.institute}")

    @classmethod
    def printDetails(cls):
        print(f"Total Student(s): {cls.total_student}")
        print(f"BRAC University Student(s): {cls.brac_student}")
        print(f"Other Institution Student(s): {cls.other_student}")

    @classmethod
    def createStudent(cls, name, dept, institute=None):
        if institute == None:
            return cls(name, dept)
        else:
            return cls(name, dept, institute)


Student.printDetails()
print("#########################")
mikasa = Student("Mikasa Ackerman", "CSE")
mikasa.individualDetail()
print("------------------------------------------")
Student.printDetails()
print("========================")
harry = Student.createStudent("Harry Potter", "Defence Against Dark Arts", "Hogwarts School")
harry.individualDetail()
print("-------------------------------------------")
Student.printDetails()
print("=========================")
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print("--------------------------------------------")
Student.printDetails()
# Out:
# Total Student(s): 0
# BRAC University Student(s): 0
# Other Institution Student(s): 0
# #########################
# Name: Mikasa Ackerman
# Department: CSE
# Institution: BRAC University
# ------------------------------------------
# Total Student(s): 1
# BRAC University Student(s): 1
# Other Institution Student(s): 0
# ...
# Name: Harry Potter
# Department: Defence Against Dark Arts
# Institution: Hogwarts School
# -------------------------------------------
# Total Student(s): 2
# BRAC University Student(s): 1
# Other Institution Student(s): 1
# ...
# Name: Levi Ackerman
# Department: CSE
# Institution: BRAC University
# --------------------------------------------
# Total Student(s): 3
# BRAC University Student(s): 2
# Other Institution Student(s): 1

# %%
# TAsk-9






# Write your code here
Student.printDetails()
print('#########################')
mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
print('========================')
harry = Student.createStudent('Harry Potter', "Defence Against Dark
Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()
print('=========================')
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()

# %%
# Task-9

class Student:
  tsc = 0
  bsc = 0
  osc = 0

  def __init__(self,n,d,ins = 'BRAC University'):
    self.n = n
    self.d = d
    self.ins = ins
    Student.tsc += 1
    if ins == 'BRAC University':
      Student.bsc += 1
    else:
      Student.osc += 1

  @classmethod
  def createStudent(cls,n,d,ins = 'BRAC University'):
    return Student(n,d,ins)

  def individualDetail(self):
    print('Name:',self.n)
    print('Department:',self.d)
    print('Institution:',self.ins)

  @classmethod
  def printDetails(cls):
    print('Total Student(s):',Student.tsc)
    print('BRAC University Student(s):',Student.bsc)
    print('Other Institution Student(s):',Student.osc)



# Write your code here
Student.printDetails()
print('#########################')
mikasa = Student('Mikasa Ackerman', "CSE")
mikasa.individualDetail()
print('------------------------------------------')
Student.printDetails()
print('========================')
harry = Student.createStudent('Harry Potter', "Defence Against Dark\
Arts", "Hogwarts School")
harry.individualDetail()
print('-------------------------------------------')
Student.printDetails()
print('=========================')
levi = Student.createStudent("Levi Ackerman", "CSE")
levi.individualDetail()
print('--------------------------------------------')
Student.printDetails()
# Out:
# Total Student(s): 0
# BRAC University Student(s): 0
# Other Institution Student(s): 0
# #########################
# Name: Mikasa Ackerman
# Department: CSE
# Institution: BRAC University
# ------------------------------------------
# Total Student(s): 1
# BRAC University Student(s): 1
# Other Institution Student(s): 0
# ...
# Name: Harry Potter
# Department: Defence Against DarkArts
# Institution: Hogwarts School
# -------------------------------------------
# Total Student(s): 2
# BRAC University Student(s): 1
# Other Institution Student(s): 1
# ...
# Name: Levi Ackerman
# Department: CSE
# Institution: BRAC University
# --------------------------------------------
# Total Student(s): 3
# BRAC University Student(s): 2
# Other Institution Student(s): 1

# %%
# Task-10

class SultansDine:
  nob = 0
  ts = 0
  # bnl = []
  # bel = []
  sl = []

  def __init__(self,bn):
    self.bn = bn
    self.price = 0
    SultansDine.nob += 1
    # SultansDine.bnl.append(bn)
    SultansDine.sl.append(self)

  def sellQuantity(self,qn):
    if qn<10:
      self.price = qn*300
      SultansDine.ts += self.price
      #SultansDine.bel.append(self.price)
    elif qn<20:
      self.price = qn*350
      SultansDine.ts += self.price
      #SultansDine.bel.append(self.price)
    else:
      self.price = qn*400
      SultansDine.ts += self.price
      #SultansDine.bel.append(self.price)

  # def branchInformation(self):
  #   print('Branch Name:',self.bn)
  #   if self.bn == 'Dhanmondi':
  #     price = self.qn*400
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)
  #   elif self.bn == 'Baily Road':
  #     price = self.qn*350
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)
  #   elif self.bn == 'Gulshan':
  #     price = self.qn*300
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)

  def branchInformation(self):
    print('Branch Name:',self.bn)
    print('Branch Sell:',self.price)


  @classmethod
  def details(cls):
    #print(SultansDine.sl)
    if SultansDine.nob == 0:
      print('Total Number of branch(s): 0')
      print('Total Sell: 0 Taka')
    else:
      print('Total Number of branch(s): ',SultansDine.nob)
      print(f'Total Sell: {SultansDine.ts} Taka')

      for i in SultansDine.sl:
        print(f'Branch Name: {i.bn}, Branch Sell: {i.price}')
        print(f"Branch consists of total sell's: {round((i.price/SultansDine.ts)*100,2)}%") 


  # have to write @classmethod here
  # def details(cls):
  #   if SultansDine.nob == 0:
  #     print('Total Number of branch(s): 0')
  #     print('Total Sell: 0 Taka')
  #   else:
  #     print('Total Number of branch(s): ',SultansDine.nob)
  #     print(f'Total Sell: {SultansDine.ts} Taka')

  #     for i in range(len(SultansDine.bnl)):
  #       print(f'Branch Name: {SultansDine.bnl[i]}, Branch Sell: {SultansDine.bel[i]}')
  #       print(f"Branch consists of total sell's: {round((SultansDine.bel[i]/SultansDine.ts)*100,2)}%")    




# Write your code here
SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000
# -----------------------------------------
# Total Number of branch(s):  1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 100.0%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250
# -----------------------------------------
# Total Number of branch(s):  2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 65.57%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 34.43%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700
# -----------------------------------------
# Total Number of branch(s):  3
# Total Sell: 17950 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 55.71%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 29.25%
# Branch Name: Gulshan, Branch Sell: 2700
# ...

# %%
# Task-10

class SultansDine:
  nob = 0
  ts = 0
  bnl = []
  bel = []
  #l = []

  def __init__(self,bn):
    self.bn = bn
    self.price = 0
    SultansDine.nob += 1
    SultansDine.bnl.append(bn)
    #SultansDine.l.append(self)

  def sellQuantity(self,qn):
    if qn<10:
      self.price = qn*300
      SultansDine.ts += self.price
      SultansDine.bel.append(self.price)
    elif qn<20:
      self.price = qn*350
      SultansDine.ts += self.price
      SultansDine.bel.append(self.price)
    else:
      self.price = qn*400
      SultansDine.ts += self.price
      SultansDine.bel.append(self.price)

  # def branchInformation(self):
  #   print('Branch Name:',self.bn)
  #   if self.bn == 'Dhanmondi':
  #     price = self.qn*400
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)
  #   elif self.bn == 'Baily Road':
  #     price = self.qn*350
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)
  #   elif self.bn == 'Gulshan':
  #     price = self.qn*300
  #     SultansDine.ts += price
  #     SultansDine.bel.append(price)
  #     print('Branch Sell:',price)

  def branchInformation(self):
    print('Branch Name:',self.bn)
    print('Branch Sell:',self.price)




  @classmethod
  def details(cls):
    if SultansDine.nob == 0:
      print('Total Number of branch(s): 0')
      print('Total Sell: 0 Taka')
    else:
      print('Total Number of branch(s): ',SultansDine.nob)
      print(f'Total Sell: {SultansDine.ts} Taka')

      for i in range(len(SultansDine.bnl)):
        print(f'Branch Name: {SultansDine.bnl[i]}, Branch Sell: {SultansDine.bel[i]}')
        print(f"Branch consists of total sell's: {round((SultansDine.bel[i]/SultansDine.ts)*100,2)}%")    




# Write your code here
SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000
# -----------------------------------------
# Total Number of branch(s):  1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 100.0%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250
# -----------------------------------------
# Total Number of branch(s):  2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 65.57%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 34.43%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700
# -----------------------------------------
# Total Number of branch(s):  3
# Total Sell: 17950 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 55.71%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 29.25%
# Branch Name: Gulshan, Branch Sell: 2700
# ...

# %%
# Task-10

class SultansDine:
  nob = 0
  ts = 0
  bnl = []
  bel = []

  def __init__(self,bn):
    self.bn = bn
    self.qn = 0
    SultansDine.nob += 1
    SultansDine.bnl.append(bn)

  def sellQuantity(self,qn):
    self.qn = qn

  def branchInformation(self):
    print('Branch Name:',self.bn)
    if self.bn == 'Dhanmondi':
      price = self.qn*400
      SultansDine.ts += price
      SultansDine.bel.append(price)
      print('Branch Sell:',price)
    elif self.bn == 'Baily Road':
      price = self.qn*350
      SultansDine.ts += price
      SultansDine.bel.append(price)
      print('Branch Sell:',price)
    elif self.bn == 'Gulshan':
      price = self.qn*300
      SultansDine.ts += price
      SultansDine.bel.append(price)
      print('Branch Sell:',price)


  @classmethod
  def details(cls):
    if SultansDine.nob == 0:
      print('Total Number of branch(s): 0')
      print('Total Sell: 0 Taka')
    else:
      print('Total Number of branch(s): ',SultansDine.nob)
      print(f'Total Sell: {SultansDine.ts} Taka')

      for i in range(len(SultansDine.bnl)):
        print(f'Branch Name: {SultansDine.bnl[i]}, Branch Sell: {SultansDine.bel[i]}')
        print(f"Branch consists of total sell's: {round((SultansDine.bel[i]/SultansDine.ts)*100,2)}%")    




# Write your code here
SultansDine.details()
print('########################')
dhanmodi = SultansDine('Dhanmondi')
dhanmodi.sellQuantity(25)
dhanmodi.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
baily_road = SultansDine('Baily Road')
baily_road.sellQuantity(15)
baily_road.branchInformation()
print('-----------------------------------------')
SultansDine.details()
print('========================')
gulshan = SultansDine('Gulshan')
gulshan.sellQuantity(9)
gulshan.branchInformation()
print('-----------------------------------------')
SultansDine.details()
# Out:
# Total Number of branch(s): 0
# Total Sell: 0 Taka
# ########################
# Branch Name: Dhanmondi
# Branch Sell: 10000
# -----------------------------------------
# Total Number of branch(s):  1
# Total Sell: 10000 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 100.0%
# ...
# Branch Name: Baily Road
# Branch Sell: 5250
# -----------------------------------------
# Total Number of branch(s):  2
# Total Sell: 15250 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 65.57%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 34.43%
# ...
# Branch Name: Gulshan
# Branch Sell: 2700
# -----------------------------------------
# Total Number of branch(s):  3
# Total Sell: 17950 Taka
# Branch Name: Dhanmondi, Branch Sell: 10000
# Branch consists of total sell's: 55.71%
# Branch Name: Baily Road, Branch Sell: 5250
# Branch consists of total sell's: 29.25%
# Branch Name: Gulshan, Branch Sell: 2700
# ...

# %%
# Task-11

class Puzzle:
  x = 0

  def methodA(self):
    Puzzle.x = 5
    z = Puzzle.x + self.methodB(Puzzle.x)
    print(Puzzle.x, z)
    z = self.methodB(z + 2) + Puzzle.x
    print(Puzzle.x, z)
    self.methodB(Puzzle.x, z)
    print(Puzzle.x, z)
  
  def methodB(self, *args):
    if len(args) == 1:
      y = args[0]
      Puzzle.x = y + Puzzle.x
      print(Puzzle.x, y)
      return Puzzle.x + 3
    else:
      z, x = args
      z = z + 1
      x = x + 1
      print(z, x)


p = Puzzle()
p.methodA()
p.methodA()
p = Puzzle()
p.methodA()
p.methodB(7)
# Out:
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 10 5
# 10 18
# 30 20
# 30 63
# 31 64
# 30 63
# 37 7
# 40

# %%
# Task-12

class FinalT6A:
  temp = 3
  def __init__(self, x, p):
    self.sum, self.y = 0, 2
    FinalT6A.temp += 3
    self.y = self.temp - p
    self.sum = self.temp + x
    print(x, self.y, self.sum)
  def methodA(self):
    x, y = 0, 0
    y = y + self.y
    x = self.y + 2 + self.temp
    self.sum = x + y + self.methodB(self.temp, y)
    print(x, y, self.sum)
  
  def methodB(self, temp, n):
    x = 0
    FinalT6A.temp += 1
    self.y = self.y + (FinalT6A.temp)
    FinalT6A.temp -= 1
    x = x + 2 + n
    self.sum = self.sum + x + self.y
    print(x, self.y, self.sum)
    return self.sum

q1 = FinalT6A(2,1)
q1.methodA()
q1.methodA()
# Out:
# 2 5 8
# 7 12 27
# 13 5 45
# 14 19 78
# 20 12 110

# %%
# Task-13

class A:
  temp = 4
  def __init__(self):
    self.y = self.temp - 2
    self.sum = self.temp + 1
    A.temp -= 2
    self.methodA(3, 4)
  def methodA(self, m, n):
    x = 0
    self.y = self.y + m + (self.temp)
    A.temp += 1
    x = x + 1 + n
    self.sum = self.sum + x + self.y
    print(x, self.y, self.sum)

class B:
  x = 0
  def __init__(self, b = None):
    self.y, self.temp, self.sum = 5, -5, 2

    if b == None:
      self.y = self.temp + 3
      self.sum = 3 + self.temp + 2
      self.temp -= 2
    else:
      self.sum = b.sum
      B.x = b.x
      b.methodB(2, 3)
  def methodA(self, m, n):
    x = 2
    self.y = self.y + m + (self.temp)
    self.temp += 1
    x = x + 5 + n
    self.sum = self.sum + x + self.y
    print(x, self.y, self.sum)
  def methodB(self, m, n):
    y = 0
    y = y + self.y

    B.x = self.y + 2 + self.temp
    self.methodA(self.x, y)
    self.sum = self.x + y + self.sum
    print(self.x, y, self.sum)

a1 = A()
b1 = B()
b2 = B(b1)
b1.methodA(1, 2)
b2.methodB(3, 2)
# Out:
# 5 7 17
# 5 -16 -11
# -7 -2 -20
# 9 -21 -32
# 12 2 14
# 2 5 21

# %%
# Task-14

class msgClass:
  def __init__(self):
    self.content = 0

class Quiz3:
  x = 0
  def __init__(self, k = None):
    self.sum, self.y = 0, 0
    if k is None:
      self.sum = 5
      Quiz3.x = 2
      self.y = 2
    else:
      self.sum = self.sum + k
      self.y = 3
      Quiz3.x += 2
  def methodA(self):
    x = 1
    y = 1
    msg = [None]
    myMsg = msgClass()
    myMsg.content = Quiz3.x
    msg[0] = myMsg
    msg[0].content = self.y + myMsg.content
    self.y = self.y + self.methodB(msg[0])
    y = self.methodB(msg[0]) + self.y
    x = y + self.methodB(msg, msg[0])
    self.sum = x + y + msg[0].content
    print(x, y, self.sum)
  def methodB(self, *args):
    if len(args) == 2:
      mg2, mg1 = args
      x = 2
      self.y = self.y + mg2[0].content
      mg2[0].content = self.y + mg1.content
      x = x + 2 + mg1.content
      self.sum = self.sum + x + self.y
      mg1.content = self.sum - mg2[0].content

      print(Quiz3.x, self.y, self.sum)
      return self.sum

    elif len(args) == 1:
      mg1, = args
      #print(mg1)
      x = 1
      y = 2
      y = self.sum + mg1.content
      self.y = y + mg1.content
      x = Quiz3.x + 5 + mg1.content
      self.sum = self.sum + x + y
      Quiz3.x = mg1.content + x + 3
      print(x, y, self.sum)
      return y


a1 = Quiz3()
a2 = Quiz3(5)
msg = msgClass()
a1.methodA()
a2.methodB(msg)
# Out:
# 15 11 31
# 35 37 103
# 44 49 211
# 291 80 527
# 49 5 59
# 5
